# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName('IoT TimeSeries') \
    .getOrCreate()

# %%
from pyspark.sql.types import *
from datetime import datetime, timedelta
import random

# Schema for IoT sensor data
schema = StructType([
    StructField("sensor_id", StringType(), False),
    StructField("timestamp", TimestampType(), False),
    StructField("location", StructType([
        StructField("latitude", DoubleType(), True),
        StructField("longitude", DoubleType(), True),
        StructField("altitude", DoubleType(), True)
    ]), True),
    StructField("readings", MapType(StringType(), DoubleType()), True),
    StructField("status", StringType(), True)
])

# Generate synthetic IoT data
base_time = datetime.now()
data = []
for i in range(50):
    sensor_data = (
        f"sensor_{i:03d}",
        base_time + timedelta(minutes=i*5),
        (40.7128 + random.uniform(-0.1, 0.1), -74.0060 + random.uniform(-0.1, 0.1), random.uniform(0, 100)),
        {
            "temperature": round(random.uniform(20, 30), 2),
            "humidity": round(random.uniform(40, 60), 2),
            "pressure": round(random.uniform(1000, 1020), 2)
        },
        random.choice(["active", "inactive", "maintenance"])
    )
    data.append(sensor_data)

df = spark.createDataFrame(data, schema)
df.show(truncate=False)
# Out:
# +----------+--------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+
# |sensor_id |timestamp                 |location                                                    |readings                                                      |status     |
# +----------+--------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+
# |sensor_000|2025-06-08 18:05:04.477832|{40.71583239247499, -73.95319832337543, 26.30292317683288}  |{temperature -> 24.1, humidity -> 56.64, pressure -> 1010.61} |active     |
# |sensor_001|2025-06-08 18:10:04.477832|{40.70302833414744, -73.95707354591102, 36.59330992040075}  |{temperature -> 23.44, humidity -> 51.64, pressure -> 1001.57}|maintenance|
# |sensor_002|2025-06-08 18:15:04.477832|{40.64648660903925, -74.01601885380882, 87.71190194056301}  |{temperature -> 29.42, humidity -> 40.96, pressure -> 1001.96}|inactive   |
# |sensor_003|2025-06-08 18:20:04.477832|{40.62316111961696, -73.94996554983904, 86.53191370958734}  |{temperature -> 20.23, humidity -> 49.97, pressure -> 1016.92}|inactive   |
# |sensor_004|2025-06-08 18:25:04.477832|{40.805713140435444, -73.94554948641034, 45.774249282882764}|{temperature -> 25.11, humidity -> 42.84, pressure -> 1012.94}|inactive   |
# |sensor_005|2025-06-08 18:30:04.477832|{40.70843962725797, -74.03083350332683, 93.91581837421585}  |{temperature -> 27.61, humidity -> 42.2, pressure -> 1004.33} |maintenance|
# |sensor_006|2025-06-08 18:35:04.477832|{40.69025302101202, -74.02221179768762, 50.17383698410809}  |{temperature -> 24.65, humidity -> 50.03, pressure -> 1009.25}|active     |
# |sensor_007|2025-06-08 18:40:04.477832|{40.6906419869384, -74.08800158229906, 93.88030352841301}   |{temperature -> 20.36, humidity -> 47.55, pressure -> 1005.82}|maintenance|
# |sensor_008|2025-06-08 18:45:04.477832|{40.690116430965546, -74.07633029602947, 89.33125897230913} |{temperature -> 27.1, humidity -> 55.5, pressure -> 1008.41}  |active     |
# |sensor_009|2025-06-08 18:50:04.477832|{40.80035235631095, -73.9418491421645, 88.80204828107286}   |{temperature -> 24.39, humidity -> 57.64, pressure -> 1019.5} |maintenance|
# |sensor_010|2025-06-08 18:55:04.477832|{40.782487449060994, -74.06207380590915, 17.96122069447592} |{temperature -> 26.77, humidity -> 56.74, pressure -> 1006.65}|active     |
# |sensor_011|2025-06-08 19:00:04.477832|{40.627853991983685, -74.07382882050273, 41.45718887445332} |{temperature -> 20.23, humidity -> 59.32, pressure -> 1007.49}|maintenance|
# |sensor_012|2025-06-08 19:05:04.477832|{40.62341447763649, -73.9963218787157, 54.553805413989195}  |{temperature -> 27.15, humidity -> 40.34, pressure -> 1004.05}|inactive   |
# |sensor_013|2025-06-08 19:10:04.477832|{40.70900859515633, -73.94809243300875, 27.092034882582706} |{temperature -> 26.29, humidity -> 59.62, pressure -> 1007.15}|inactive   |
# |sensor_014|2025-06-08 19:15:04.477832|{40.62948961109687, -73.92169956750182, 89.90551165888321}  |{temperature -> 29.14, humidity -> 53.74, pressure -> 1003.9} |maintenance|
# |sensor_015|2025-06-08 19:20:04.477832|{40.70536211245254, -74.04255935208847, 5.1106925521737345} |{temperature -> 23.81, humidity -> 56.02, pressure -> 1006.5} |active     |
# |sensor_016|2025-06-08 19:25:04.477832|{40.74963994303316, -74.02340185653078, 60.61355430892306}  |{temperature -> 22.44, humidity -> 50.68, pressure -> 1013.46}|maintenance|
# |sensor_017|2025-06-08 19:30:04.477832|{40.62118781355235, -74.05194016523805, 13.43593571226176}  |{temperature -> 26.42, humidity -> 56.16, pressure -> 1008.96}|inactive   |
# |sensor_018|2025-06-08 19:35:04.477832|{40.7688523010221, -73.9757833122034, 12.007554400912746}   |{temperature -> 26.04, humidity -> 44.48, pressure -> 1014.94}|maintenance|
# |sensor_019|2025-06-08 19:40:04.477832|{40.63903022888646, -74.08425809719868, 18.2234653275111}   |{temperature -> 25.44, humidity -> 46.04, pressure -> 1001.19}|maintenance|
# +----------+--------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+
# only showing top 20 rows

# %%
# create a temporary view for SQL queries
df.createOrReplaceTempView("iot_sensors")

# %% [markdown]
# # Single Sensor Overtime

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from datetime import datetime, timedelta
import random

# Schema for IoT sensor data
schema = StructType([
    StructField("sensor_id", StringType(), False),
    StructField("timestamp", TimestampType(), False),
    StructField("location", StructType([
        StructField("latitude", DoubleType(), True),
        StructField("longitude", DoubleType(), True),
        StructField("altitude", DoubleType(), True)
    ]), True),
    StructField("readings", MapType(StringType(), DoubleType()), True),
    StructField("status", StringType(), True)
])

# Generate synthetic IoT data
base_time = datetime.now()
data = []
for sensor_id in range(10):
    for i in range(50):
        sensor_data = (
            f"sensor_{sensor_id:03d}",
            base_time + timedelta(minutes=i*5),
            (40.7128 + random.uniform(-0.1, 0.1), -74.0060 + random.uniform(-0.1, 0.1), random.uniform(0, 100)),
            {
                "temperature": round(random.uniform(20, 30), 2),
                "humidity": round(random.uniform(40, 60), 2),
                "pressure": round(random.uniform(1000, 1020), 2)
            },
            random.choice(["active", "inactive", "maintenance"])
        )
        data.append(sensor_data)

df = spark.createDataFrame(data, schema)
df.show(truncate=False)
# Out:
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+
# |sensor_id |timestamp                |location                                                    |readings                                                      |status     |
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+
# |sensor_000|2025-06-10 09:16:38.23774|{40.676752359137545, -73.90856554030503, 19.944268473625925}|{temperature -> 28.87, humidity -> 44.55, pressure -> 1013.33}|maintenance|
# |sensor_000|2025-06-10 09:21:38.23774|{40.71272586321469, -74.01885875701497, 65.87936777648402}  |{temperature -> 20.49, humidity -> 51.66, pressure -> 1014.04}|active     |
# |sensor_000|2025-06-10 09:26:38.23774|{40.74857491958641, -74.00195301153394, 70.04078332196812}  |{temperature -> 26.27, humidity -> 56.41, pressure -> 1001.33}|active     |
# |sensor_000|2025-06-10 09:31:38.23774|{40.77751802972562, -73.93255376674577, 72.30913634764134}  |{temperature -> 28.7, humidity -> 53.11, pressure -> 1001.35} |maintenance|
# |sensor_000|2025-06-10 09:36:38.23774|{40.73495804290343, -73.94344728295721, 92.87228546019473}  |{temperature -> 29.49, humidity -> 54.34, pressure -> 1001.55}|active     |
# |sensor_000|2025-06-10 09:41:38.23774|{40.64225823742316, -74.0058347501132, 79.98564240287028}   |{temperature -> 24.87, humidity -> 53.11, pressure -> 1003.16}|active     |
# |sensor_000|2025-06-10 09:46:38.23774|{40.809587214097505, -74.05872002751214, 42.88145725952972} |{temperature -> 20.82, humidity -> 50.71, pressure -> 1013.78}|maintenance|
# |sensor_000|2025-06-10 09:51:38.23774|{40.74363742139164, -74.0840287329428, 11.433544881106993}  |{temperature -> 22.83, humidity -> 58.15, pressure -> 1014.41}|active     |
# |sensor_000|2025-06-10 09:56:38.23774|{40.80193481370528, -73.99135296036239, 99.89192640659327}  |{temperature -> 21.5, humidity -> 46.34, pressure -> 1017.56} |maintenance|
# |sensor_000|2025-06-10 10:01:38.23774|{40.774281169096945, -73.98243705349458, 45.89653094498777} |{temperature -> 22.49, humidity -> 40.66, pressure -> 1006.71}|active     |
# |sensor_000|2025-06-10 10:06:38.23774|{40.68907648030181, -74.06278169704618, 11.725114835631933} |{temperature -> 29.56, humidity -> 58.2, pressure -> 1013.39} |inactive   |
# |sensor_000|2025-06-10 10:11:38.23774|{40.725432240902165, -74.10204529520577, 35.3856792218142}  |{temperature -> 29.76, humidity -> 46.11, pressure -> 1011.26}|maintenance|
# |sensor_000|2025-06-10 10:16:38.23774|{40.714050164673765, -74.02789235164408, 59.182827429389185}|{temperature -> 21.82, humidity -> 51.77, pressure -> 1010.24}|inactive   |
# |sensor_000|2025-06-10 10:21:38.23774|{40.66763290482291, -73.95912401515888, 77.16203204038649}  |{temperature -> 20.67, humidity -> 54.35, pressure -> 1000.34}|inactive   |
# |sensor_000|2025-06-10 10:26:38.23774|{40.66951809346745, -74.08826946798693, 53.520862158806416} |{temperature -> 26.47, humidity -> 48.97, pressure -> 1007.45}|inactive   |
# |sensor_000|2025-06-10 10:31:38.23774|{40.7281255476135, -74.01914806667878, 56.20072229577113}   |{temperature -> 21.53, humidity -> 40.22, pressure -> 1017.96}|active     |
# |sensor_000|2025-06-10 10:36:38.23774|{40.68117438694662, -74.07650034242681, 94.54071114811586}  |{temperature -> 21.85, humidity -> 47.79, pressure -> 1004.78}|maintenance|
# |sensor_000|2025-06-10 10:41:38.23774|{40.61434608307676, -74.05303710480071, 1.863252580719521}  |{temperature -> 21.66, humidity -> 57.99, pressure -> 1017.71}|inactive   |
# |sensor_000|2025-06-10 10:46:38.23774|{40.74188065678107, -74.06019130069481, 41.47546076290662}  |{temperature -> 24.26, humidity -> 55.5, pressure -> 1003.9}  |inactive   |
# |sensor_000|2025-06-10 10:51:38.23774|{40.614739796756, -73.94276222204306, 6.264555014757256}    |{temperature -> 28.0, humidity -> 47.93, pressure -> 1003.48} |inactive   |
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+
# only showing top 20 rows

# %%
df.orderBy("timestamp", "sensor_id").show(25, truncate=False)
# Out:
# +----------+--------------------------+-----------------------------------------------------------+--------------------------------------------------------------+-----------+
# |sensor_id |timestamp                 |location                                                   |readings                                                      |status     |
# +----------+--------------------------+-----------------------------------------------------------+--------------------------------------------------------------+-----------+
# |sensor_000|2025-06-09 13:04:23.495049|{40.75150213848252, -73.92060981760952, 9.279084177906661} |{temperature -> 22.07, humidity -> 45.59, pressure -> 1012.22}|active     |
# |sensor_001|2025-06-09 13:04:23.495049|{40.71220830802617, -73.93228665689061, 48.4100003910702}  |{temperature -> 20.02, humidity -> 55.69, pressure -> 1009.13}|inactive   |
# |sensor_002|2025-06-09 13:04:23.495049|{40.6495966668836, -74.04535417348842, 71.74289080255328}  |{temperature -> 22.5, humidity -> 45.98, pressure -> 1004.23} |inactive   |
# |sensor_003|2025-06-09 13:04:23.495049|{40.74226996944126, -74.00145147061609, 32.048907555185394}|{temperature -> 29.96, humidity -> 55.64, pressure -> 1013.24}|inactive   |
# |sensor_004|2025-06-09 13:04:23.495049|{40.7972579717891, -73.97735928667394, 1.6467723759894581} |{temperature -> 22.75, humidity -> 48.06, pressure -> 1003.84}|active     |
# |sensor_005|2025-06-09 13:04:23.495049|{40.72505994267179, -74.07961476666664, 76.25300057087905} |{temperature -> 26.61, humidity -> 46.94, pressure -> 1019.4} |inactive   |
# |sensor_006|2025-06-09 13:04:23.495049|{40.68159841845912, -74.05571496403277, 3.8100984297433804}|{temperature -> 26.55, humidity -> 51.24, pressure -> 1014.68}|maintenance|
# |sensor_007|2025-06-09 13:04:23.495049|{40.73259423246007, -73.99233920354335, 60.40106082871459} |{temperature -> 22.22, humidity -> 46.45, pressure -> 1014.94}|active     |
# |sensor_008|2025-06-09 13:04:23.495049|{40.80116980308725, -74.1030860734178, 25.420675286152694} |{temperature -> 21.46, humidity -> 42.52, pressure -> 1018.69}|maintenance|
# |sensor_009|2025-06-09 13:04:23.495049|{40.74274898676354, -74.07212491298657, 60.59592879068782} |{temperature -> 26.61, humidity -> 54.38, pressure -> 1015.51}|active     |
# |sensor_000|2025-06-09 13:09:23.495049|{40.63527953792914, -73.9685280725309, 88.80809613033718}  |{temperature -> 29.82, humidity -> 50.13, pressure -> 1001.28}|maintenance|
# |sensor_001|2025-06-09 13:09:23.495049|{40.725243936087104, -74.05419264155003, 35.02871537160437}|{temperature -> 20.34, humidity -> 48.0, pressure -> 1019.12} |maintenance|
# |sensor_002|2025-06-09 13:09:23.495049|{40.80481894080726, -74.01349103594711, 35.179647717535346}|{temperature -> 28.08, humidity -> 53.44, pressure -> 1018.08}|maintenance|
# |sensor_003|2025-06-09 13:09:23.495049|{40.72996644839865, -73.99967407220524, 18.6742762419262}  |{temperature -> 22.11, humidity -> 54.23, pressure -> 1007.3} |maintenance|
# |sensor_004|2025-06-09 13:09:23.495049|{40.73167202053303, -74.0899591527243, 66.85148674462772}  |{temperature -> 24.4, humidity -> 46.15, pressure -> 1005.7}  |inactive   |
# |sensor_005|2025-06-09 13:09:23.495049|{40.71975037328958, -74.0450661530178, 91.86410749602783}  |{temperature -> 25.36, humidity -> 56.77, pressure -> 1018.97}|active     |
# |sensor_006|2025-06-09 13:09:23.495049|{40.68031089501435, -73.91747828066993, 2.7400757534171705}|{temperature -> 22.31, humidity -> 56.82, pressure -> 1008.63}|inactive   |
# |sensor_007|2025-06-09 13:09:23.495049|{40.76514980748386, -74.07731911224097, 36.764994981960506}|{temperature -> 21.16, humidity -> 41.85, pressure -> 1010.54}|inactive   |
# |sensor_008|2025-06-09 13:09:23.495049|{40.75413290170236, -74.06584251994845, 48.41191952334659} |{temperature -> 29.58, humidity -> 51.29, pressure -> 1015.08}|active     |
# |sensor_009|2025-06-09 13:09:23.495049|{40.71512578564627, -73.9876826298528, 66.18651084124144}  |{temperature -> 25.25, humidity -> 50.82, pressure -> 1011.07}|maintenance|
# |sensor_000|2025-06-09 13:14:23.495049|{40.67413341143455, -73.91975861687318, 85.67626606825345} |{temperature -> 22.67, humidity -> 58.98, pressure -> 1016.42}|maintenance|
# |sensor_001|2025-06-09 13:14:23.495049|{40.62102665199596, -74.07418581773827, 69.64993313212562} |{temperature -> 20.4, humidity -> 50.74, pressure -> 1014.19} |inactive   |
# |sensor_002|2025-06-09 13:14:23.495049|{40.698917120466184, -74.00247530427524, 96.44897079461194}|{temperature -> 22.25, humidity -> 58.04, pressure -> 1009.71}|inactive   |
# |sensor_003|2025-06-09 13:14:23.495049|{40.77223851154701, -74.0549893265381, 61.543100731220555} |{temperature -> 22.08, humidity -> 46.21, pressure -> 1008.89}|inactive   |
# |sensor_004|2025-06-09 13:14:23.495049|{40.63004270241609, -73.92460449564118, 76.4380008090741}  |{temperature -> 24.38, humidity -> 46.29, pressure -> 1007.64}|maintenance|
# +----------+--------------------------+-----------------------------------------------------------+--------------------------------------------------------------+-----------+
# only showing top 25 rows

# %%
df_coast = df.withColumn("latitude_block", round(col("location.latitude"), 4)) \
    .withColumn("region", when(col("latitude_block").between(40.7, 40.8), "East Coast") \
        .when(col("latitude_block").between(40.6, 40.7), "Central") \
        .when(col("latitude_block").between(40.5, 40.6), "West Coast") \
        .otherwise("Out-of-Bounds")) 

df_coast.show(truncate=False)
# Out:
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+--------------+-------------+
# |sensor_id |timestamp                |location                                                    |readings                                                      |status     |latitude_block|region       |
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+--------------+-------------+
# |sensor_000|2025-06-10 09:16:38.23774|{40.676752359137545, -73.90856554030503, 19.944268473625925}|{temperature -> 28.87, humidity -> 44.55, pressure -> 1013.33}|maintenance|40.6768       |West Coast   |
# |sensor_000|2025-06-10 09:21:38.23774|{40.71272586321469, -74.01885875701497, 65.87936777648402}  |{temperature -> 20.49, humidity -> 51.66, pressure -> 1014.04}|active     |40.7127       |East Coast   |
# |sensor_000|2025-06-10 09:26:38.23774|{40.74857491958641, -74.00195301153394, 70.04078332196812}  |{temperature -> 26.27, humidity -> 56.41, pressure -> 1001.33}|active     |40.7486       |East Coast   |
# |sensor_000|2025-06-10 09:31:38.23774|{40.77751802972562, -73.93255376674577, 72.30913634764134}  |{temperature -> 28.7, humidity -> 53.11, pressure -> 1001.35} |maintenance|40.7775       |East Coast   |
# |sensor_000|2025-06-10 09:36:38.23774|{40.73495804290343, -73.94344728295721, 92.87228546019473}  |{temperature -> 29.49, humidity -> 54.34, pressure -> 1001.55}|active     |40.735        |East Coast   |
# |sensor_000|2025-06-10 09:41:38.23774|{40.64225823742316, -74.0058347501132, 79.98564240287028}   |{temperature -> 24.87, humidity -> 53.11, pressure -> 1003.16}|active     |40.6423       |West Coast   |
# |sensor_000|2025-06-10 09:46:38.23774|{40.809587214097505, -74.05872002751214, 42.88145725952972} |{temperature -> 20.82, humidity -> 50.71, pressure -> 1013.78}|maintenance|40.8096       |Out-of-Bounds|
# |sensor_000|2025-06-10 09:51:38.23774|{40.74363742139164, -74.0840287329428, 11.433544881106993}  |{temperature -> 22.83, humidity -> 58.15, pressure -> 1014.41}|active     |40.7436       |East Coast   |
# |sensor_000|2025-06-10 09:56:38.23774|{40.80193481370528, -73.99135296036239, 99.89192640659327}  |{temperature -> 21.5, humidity -> 46.34, pressure -> 1017.56} |maintenance|40.8019       |Out-of-Bounds|
# |sensor_000|2025-06-10 10:01:38.23774|{40.774281169096945, -73.98243705349458, 45.89653094498777} |{temperature -> 22.49, humidity -> 40.66, pressure -> 1006.71}|active     |40.7743       |East Coast   |
# |sensor_000|2025-06-10 10:06:38.23774|{40.68907648030181, -74.06278169704618, 11.725114835631933} |{temperature -> 29.56, humidity -> 58.2, pressure -> 1013.39} |inactive   |40.6891       |West Coast   |
# |sensor_000|2025-06-10 10:11:38.23774|{40.725432240902165, -74.10204529520577, 35.3856792218142}  |{temperature -> 29.76, humidity -> 46.11, pressure -> 1011.26}|maintenance|40.7254       |East Coast   |
# |sensor_000|2025-06-10 10:16:38.23774|{40.714050164673765, -74.02789235164408, 59.182827429389185}|{temperature -> 21.82, humidity -> 51.77, pressure -> 1010.24}|inactive   |40.7141       |East Coast   |
# |sensor_000|2025-06-10 10:21:38.23774|{40.66763290482291, -73.95912401515888, 77.16203204038649}  |{temperature -> 20.67, humidity -> 54.35, pressure -> 1000.34}|inactive   |40.6676       |West Coast   |
# |sensor_000|2025-06-10 10:26:38.23774|{40.66951809346745, -74.08826946798693, 53.520862158806416} |{temperature -> 26.47, humidity -> 48.97, pressure -> 1007.45}|inactive   |40.6695       |West Coast   |
# |sensor_000|2025-06-10 10:31:38.23774|{40.7281255476135, -74.01914806667878, 56.20072229577113}   |{temperature -> 21.53, humidity -> 40.22, pressure -> 1017.96}|active     |40.7281       |East Coast   |
# |sensor_000|2025-06-10 10:36:38.23774|{40.68117438694662, -74.07650034242681, 94.54071114811586}  |{temperature -> 21.85, humidity -> 47.79, pressure -> 1004.78}|maintenance|40.6812       |West Coast   |
# |sensor_000|2025-06-10 10:41:38.23774|{40.61434608307676, -74.05303710480071, 1.863252580719521}  |{temperature -> 21.66, humidity -> 57.99, pressure -> 1017.71}|inactive   |40.6143       |West Coast   |
# |sensor_000|2025-06-10 10:46:38.23774|{40.74188065678107, -74.06019130069481, 41.47546076290662}  |{temperature -> 24.26, humidity -> 55.5, pressure -> 1003.9}  |inactive   |40.7419       |East Coast   |
# |sensor_000|2025-06-10 10:51:38.23774|{40.614739796756, -73.94276222204306, 6.264555014757256}    |{temperature -> 28.0, humidity -> 47.93, pressure -> 1003.48} |inactive   |40.6147       |West Coast   |
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+--------------+-------------+
# only showing top 20 rows

# %%
# 15-minute intervals
df = df.withColumn("minute_15_bucket", 
                   from_unixtime(
                       floor(unix_timestamp("timestamp") / (15 * 60)) * (15 * 60)
                   ).cast("timestamp"))
df.show(truncate=False)
# Out:
# +----------+--------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+-------------------+
# |sensor_id |timestamp                 |location                                                    |readings                                                      |status     |minute_15_bucket   |
# +----------+--------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+-------------------+
# |sensor_000|2025-06-09 13:04:23.495049|{40.75150213848252, -73.92060981760952, 9.279084177906661}  |{temperature -> 22.07, humidity -> 45.59, pressure -> 1012.22}|active     |2025-06-09 13:00:00|
# |sensor_000|2025-06-09 13:09:23.495049|{40.63527953792914, -73.9685280725309, 88.80809613033718}   |{temperature -> 29.82, humidity -> 50.13, pressure -> 1001.28}|maintenance|2025-06-09 13:00:00|
# |sensor_000|2025-06-09 13:14:23.495049|{40.67413341143455, -73.91975861687318, 85.67626606825345}  |{temperature -> 22.67, humidity -> 58.98, pressure -> 1016.42}|maintenance|2025-06-09 13:00:00|
# |sensor_000|2025-06-09 13:19:23.495049|{40.6331022713429, -73.91355957842953, 4.011865229060907}   |{temperature -> 22.13, humidity -> 59.24, pressure -> 1015.49}|maintenance|2025-06-09 13:15:00|
# |sensor_000|2025-06-09 13:24:23.495049|{40.734627721018214, -74.07488671122627, 53.14196870062151} |{temperature -> 27.48, humidity -> 47.45, pressure -> 1005.75}|inactive   |2025-06-09 13:15:00|
# |sensor_000|2025-06-09 13:29:23.495049|{40.710264988417094, -73.92440979758803, 48.232962378728814}|{temperature -> 22.64, humidity -> 52.04, pressure -> 1009.59}|active     |2025-06-09 13:15:00|
# |sensor_000|2025-06-09 13:34:23.495049|{40.798897790873305, -73.99619118343307, 33.27662171357312} |{temperature -> 25.77, humidity -> 53.28, pressure -> 1009.93}|inactive   |2025-06-09 13:30:00|
# |sensor_000|2025-06-09 13:39:23.495049|{40.665447740874775, -74.04220309718912, 6.566789702781284} |{temperature -> 21.85, humidity -> 48.58, pressure -> 1012.61}|maintenance|2025-06-09 13:30:00|
# |sensor_000|2025-06-09 13:44:23.495049|{40.811998966245476, -74.03376204767464, 74.22538499841728} |{temperature -> 27.65, humidity -> 44.79, pressure -> 1019.61}|inactive   |2025-06-09 13:30:00|
# |sensor_000|2025-06-09 13:49:23.495049|{40.69964821660729, -74.07862476060697, 94.54718380824205}  |{temperature -> 23.97, humidity -> 44.36, pressure -> 1012.67}|active     |2025-06-09 13:45:00|
# |sensor_000|2025-06-09 13:54:23.495049|{40.65613985145099, -73.93776622241685, 58.82675991563657}  |{temperature -> 22.14, humidity -> 57.63, pressure -> 1006.71}|active     |2025-06-09 13:45:00|
# |sensor_000|2025-06-09 13:59:23.495049|{40.81205650898491, -74.09408255742738, 20.57348376438949}  |{temperature -> 24.7, humidity -> 41.51, pressure -> 1004.47} |maintenance|2025-06-09 13:45:00|
# |sensor_000|2025-06-09 14:04:23.495049|{40.62079559637665, -74.03155890629093, 27.586352516440204} |{temperature -> 22.22, humidity -> 45.54, pressure -> 1009.47}|inactive   |2025-06-09 14:00:00|
# |sensor_000|2025-06-09 14:09:23.495049|{40.794496908689574, -74.10290555052026, 17.90137219114788} |{temperature -> 20.6, humidity -> 55.62, pressure -> 1015.68} |maintenance|2025-06-09 14:00:00|
# |sensor_000|2025-06-09 14:14:23.495049|{40.67357523255618, -74.03043095038181, 47.37510791791523}  |{temperature -> 22.36, humidity -> 42.48, pressure -> 1003.11}|maintenance|2025-06-09 14:00:00|
# |sensor_000|2025-06-09 14:19:23.495049|{40.71204732903084, -74.03520041430622, 47.73370142847932}  |{temperature -> 26.84, humidity -> 42.18, pressure -> 1018.16}|maintenance|2025-06-09 14:15:00|
# |sensor_000|2025-06-09 14:24:23.495049|{40.74326843960929, -74.10271043636516, 53.09724191421663}  |{temperature -> 23.33, humidity -> 50.89, pressure -> 1016.69}|inactive   |2025-06-09 14:15:00|
# |sensor_000|2025-06-09 14:29:23.495049|{40.71640804619875, -74.01493494421344, 26.98962272747484}  |{temperature -> 26.81, humidity -> 44.92, pressure -> 1013.28}|active     |2025-06-09 14:15:00|
# |sensor_000|2025-06-09 14:34:23.495049|{40.73917106232907, -73.93242766963311, 59.993098853569805} |{temperature -> 23.76, humidity -> 55.56, pressure -> 1011.08}|active     |2025-06-09 14:30:00|
# |sensor_000|2025-06-09 14:39:23.495049|{40.679881531645705, -74.04200683361066, 23.642712478380556}|{temperature -> 24.57, humidity -> 52.02, pressure -> 1006.06}|maintenance|2025-06-09 14:30:00|
# +----------+--------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+-------------------+
# only showing top 20 rows

# %%
time_window = Window.partitionBy("sensor_id").orderBy("timestamp").rowsBetween(-11,0) # a rolling hours
df_lag = df.withColumn("rolliing_avg_temp", avg(col("readings.temperature")).over(time_window)) \
    .withColumn("lat_change", col("location.latitude") - lag("location.latitude").over(Window.partitionBy("sensor_id").orderBy("timestamp")))

df_lag.orderBy("sensor_id","timestamp").show(25, truncate=False)
# Out:
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+------------------+---------------------+
# |sensor_id |timestamp                |location                                                    |readings                                                      |status     |rolliing_avg_temp |lat_change           |
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+------------------+---------------------+
# |sensor_000|2025-06-10 09:16:38.23774|{40.676752359137545, -73.90856554030503, 19.944268473625925}|{temperature -> 28.87, humidity -> 44.55, pressure -> 1013.33}|maintenance|28.87             |NULL                 |
# |sensor_000|2025-06-10 09:21:38.23774|{40.71272586321469, -74.01885875701497, 65.87936777648402}  |{temperature -> 20.49, humidity -> 51.66, pressure -> 1014.04}|active     |24.68             |0.03597350407714828  |
# |sensor_000|2025-06-10 09:26:38.23774|{40.74857491958641, -74.00195301153394, 70.04078332196812}  |{temperature -> 26.27, humidity -> 56.41, pressure -> 1001.33}|active     |25.209999999999997|0.03584905637171687  |
# |sensor_000|2025-06-10 09:31:38.23774|{40.77751802972562, -73.93255376674577, 72.30913634764134}  |{temperature -> 28.7, humidity -> 53.11, pressure -> 1001.35} |maintenance|26.0825           |0.028943110139209693 |
# |sensor_000|2025-06-10 09:36:38.23774|{40.73495804290343, -73.94344728295721, 92.87228546019473}  |{temperature -> 29.49, humidity -> 54.34, pressure -> 1001.55}|active     |26.764            |-0.042559986822190865|
# |sensor_000|2025-06-10 09:41:38.23774|{40.64225823742316, -74.0058347501132, 79.98564240287028}   |{temperature -> 24.87, humidity -> 53.11, pressure -> 1003.16}|active     |26.448333333333334|-0.09269980548027235 |
# |sensor_000|2025-06-10 09:46:38.23774|{40.809587214097505, -74.05872002751214, 42.88145725952972} |{temperature -> 20.82, humidity -> 50.71, pressure -> 1013.78}|maintenance|25.64428571428571 |0.16732897667434798  |
# |sensor_000|2025-06-10 09:51:38.23774|{40.74363742139164, -74.0840287329428, 11.433544881106993}  |{temperature -> 22.83, humidity -> 58.15, pressure -> 1014.41}|active     |25.292499999999997|-0.0659497927058652  |
# |sensor_000|2025-06-10 09:56:38.23774|{40.80193481370528, -73.99135296036239, 99.89192640659327}  |{temperature -> 21.5, humidity -> 46.34, pressure -> 1017.56} |maintenance|24.87111111111111 |0.05829739231364073  |
# |sensor_000|2025-06-10 10:01:38.23774|{40.774281169096945, -73.98243705349458, 45.89653094498777} |{temperature -> 22.49, humidity -> 40.66, pressure -> 1006.71}|active     |24.633            |-0.027653644608335526|
# |sensor_000|2025-06-10 10:06:38.23774|{40.68907648030181, -74.06278169704618, 11.725114835631933} |{temperature -> 29.56, humidity -> 58.2, pressure -> 1013.39} |inactive   |25.08090909090909 |-0.08520468879513743 |
# |sensor_000|2025-06-10 10:11:38.23774|{40.725432240902165, -74.10204529520577, 35.3856792218142}  |{temperature -> 29.76, humidity -> 46.11, pressure -> 1011.26}|maintenance|25.47083333333333 |0.03635576060035817  |
# |sensor_000|2025-06-10 10:16:38.23774|{40.714050164673765, -74.02789235164408, 59.182827429389185}|{temperature -> 21.82, humidity -> 51.77, pressure -> 1010.24}|inactive   |24.88333333333333 |-0.011382076228400706|
# |sensor_000|2025-06-10 10:21:38.23774|{40.66763290482291, -73.95912401515888, 77.16203204038649}  |{temperature -> 20.67, humidity -> 54.35, pressure -> 1000.34}|inactive   |24.898333333333337|-0.04641725985085543 |
# |sensor_000|2025-06-10 10:26:38.23774|{40.66951809346745, -74.08826946798693, 53.520862158806416} |{temperature -> 26.47, humidity -> 48.97, pressure -> 1007.45}|inactive   |24.915000000000003|0.0018851886445432342|
# |sensor_000|2025-06-10 10:31:38.23774|{40.7281255476135, -74.01914806667878, 56.20072229577113}   |{temperature -> 21.53, humidity -> 40.22, pressure -> 1017.96}|active     |24.317499999999995|0.058607454146049065 |
# |sensor_000|2025-06-10 10:36:38.23774|{40.68117438694662, -74.07650034242681, 94.54071114811586}  |{temperature -> 21.85, humidity -> 47.79, pressure -> 1004.78}|maintenance|23.680833333333336|-0.04695116066687888 |
# |sensor_000|2025-06-10 10:41:38.23774|{40.61434608307676, -74.05303710480071, 1.863252580719521}  |{temperature -> 21.66, humidity -> 57.99, pressure -> 1017.71}|inactive   |23.413333333333338|-0.06682830386986183 |
# |sensor_000|2025-06-10 10:46:38.23774|{40.74188065678107, -74.06019130069481, 41.47546076290662}  |{temperature -> 24.26, humidity -> 55.5, pressure -> 1003.9}  |inactive   |23.7              |0.12753457370430965  |
# |sensor_000|2025-06-10 10:51:38.23774|{40.614739796756, -73.94276222204306, 6.264555014757256}    |{temperature -> 28.0, humidity -> 47.93, pressure -> 1003.48} |inactive   |24.13083333333333 |-0.1271408600250723  |
# |sensor_000|2025-06-10 10:56:38.23774|{40.6958494817553, -74.00195144684412, 33.220691348810774}  |{temperature -> 21.24, humidity -> 43.23, pressure -> 1009.88}|maintenance|24.109166666666663|0.08110968499930493  |
# |sensor_000|2025-06-10 11:01:38.23774|{40.61719269716634, -74.09495649435192, 14.423977029161216} |{temperature -> 22.15, humidity -> 54.23, pressure -> 1008.39}|active     |24.08083333333333 |-0.07865678458896497 |
# |sensor_000|2025-06-10 11:06:38.23774|{40.73947453528274, -74.02381645733074, 83.58463917266734}  |{temperature -> 29.45, humidity -> 49.59, pressure -> 1011.25}|active     |24.071666666666662|0.12228183811640037  |
# |sensor_000|2025-06-10 11:11:38.23774|{40.81143560926259, -73.97702200677946, 86.03928781010121}  |{temperature -> 26.16, humidity -> 45.44, pressure -> 1009.37}|inactive   |23.771666666666672|0.07196107397984974  |
# |sensor_000|2025-06-10 11:16:38.23774|{40.698609088454944, -74.08256449426584, 26.99644043261805} |{temperature -> 21.4, humidity -> 46.88, pressure -> 1005.58} |active     |23.736666666666665|-0.11282652080764421 |
# +----------+-------------------------+------------------------------------------------------------+--------------------------------------------------------------+-----------+------------------+---------------------+
# only showing top 25 rows

# %%
df_timestats = df_lag.withColumn("rolliing_avg_temp", avg(col("readings.temperature")).over(time_window)) \
    .withColumn("lat_change_hr", round(avg(col("lat_change")).over(time_window),4))


df_timestats.select("sensor_id", "timestamp", "readings.temperature", "rolliing_avg_temp", "lat_change", "lat_change_hr").orderBy("sensor_id", "timestamp").show(25, truncate=False)
# Out:
# +----------+-------------------------+-----------+------------------+---------------------+-------------+
# |sensor_id |timestamp                |temperature|rolliing_avg_temp |lat_change           |lat_change_hr|
# +----------+-------------------------+-----------+------------------+---------------------+-------------+
# |sensor_000|2025-06-10 09:16:38.23774|28.87      |28.87             |NULL                 |NULL         |
# |sensor_000|2025-06-10 09:21:38.23774|20.49      |24.68             |0.03597350407714828  |0.036        |
# |sensor_000|2025-06-10 09:26:38.23774|26.27      |25.209999999999997|0.03584905637171687  |0.0359       |
# |sensor_000|2025-06-10 09:31:38.23774|28.7       |26.0825           |0.028943110139209693 |0.0336       |
# |sensor_000|2025-06-10 09:36:38.23774|29.49      |26.764            |-0.042559986822190865|0.0146       |
# |sensor_000|2025-06-10 09:41:38.23774|24.87      |26.448333333333334|-0.09269980548027235 |-0.0069      |
# |sensor_000|2025-06-10 09:46:38.23774|20.82      |25.64428571428571 |0.16732897667434798  |0.0221       |
# |sensor_000|2025-06-10 09:51:38.23774|22.83      |25.292499999999997|-0.0659497927058652  |0.0096       |
# |sensor_000|2025-06-10 09:56:38.23774|21.5       |24.87111111111111 |0.05829739231364073  |0.0156       |
# |sensor_000|2025-06-10 10:01:38.23774|22.49      |24.633            |-0.027653644608335526|0.0108       |
# |sensor_000|2025-06-10 10:06:38.23774|29.56      |25.08090909090909 |-0.08520468879513743 |0.0012       |
# |sensor_000|2025-06-10 10:11:38.23774|29.76      |25.47083333333333 |0.03635576060035817  |0.0044       |
# |sensor_000|2025-06-10 10:16:38.23774|21.82      |24.88333333333333 |-0.011382076228400706|0.0031       |
# |sensor_000|2025-06-10 10:21:38.23774|20.67      |24.898333333333337|-0.04641725985085543 |-0.0038      |
# |sensor_000|2025-06-10 10:26:38.23774|26.47      |24.915000000000003|0.0018851886445432342|-0.0066      |
# |sensor_000|2025-06-10 10:31:38.23774|21.53      |24.317499999999995|0.058607454146049065 |-0.0041      |
# |sensor_000|2025-06-10 10:36:38.23774|21.85      |23.680833333333336|-0.04695116066687888 |-0.0045      |
# |sensor_000|2025-06-10 10:41:38.23774|21.66      |23.413333333333338|-0.06682830386986183 |-0.0023      |
# |sensor_000|2025-06-10 10:46:38.23774|24.26      |23.7              |0.12753457370430965  |-0.0056      |
# |sensor_000|2025-06-10 10:51:38.23774|28.0       |24.13083333333333 |-0.1271408600250723  |-0.0107      |
# |sensor_000|2025-06-10 10:56:38.23774|21.24      |24.109166666666663|0.08110968499930493  |-0.0088      |
# |sensor_000|2025-06-10 11:01:38.23774|22.15      |24.08083333333333 |-0.07865678458896497 |-0.0131      |
# |sensor_000|2025-06-10 11:06:38.23774|29.45      |24.071666666666662|0.12228183811640037  |0.0042       |
# |sensor_000|2025-06-10 11:11:38.23774|26.16      |23.771666666666672|0.07196107397984974  |0.0072       |
# |sensor_000|2025-06-10 11:16:38.23774|21.4       |23.736666666666665|-0.11282652080764421 |-0.0013      |
# +----------+-------------------------+-----------+------------------+---------------------+-------------+
# only showing top 25 rows
