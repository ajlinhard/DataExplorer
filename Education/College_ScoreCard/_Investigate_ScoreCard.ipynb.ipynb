# %%
import pandas as pd
import numpy as np

file_root = r'C:\Users\dalej\OneDrive\Documents\Data\College_Scorecard_Raw_Data_05192025\College_Scorecard_Raw_Data_05192025'

# %% [markdown]
# # Testing String Parsing
# Data is from https://collegescorecard.ed.gov/data

# %%
df_csv = pd.read_csv(file_root + r'\FieldOfStudyData1415_1516_PP.csv')
df_csv.head(10)
# Out:
#      UNITID  OPEID6                    INSTNM CONTROL  MAIN  CIPCODE  \
# 0  100654.0    1002  Alabama A & M University  Public     1      100
# 1  100654.0    1002  Alabama A & M University  Public     1      101
# 2  100654.0    1002  Alabama A & M University  Public     1      109
# 3  100654.0    1002  Alabama A & M University  Public     1      110
# 4  100654.0    1002  Alabama A & M University  Public     1      110
# 5  100654.0    1002  Alabama A & M University  Public     1      110
# 6  100654.0    1002  Alabama A & M University  Public     1      111
# 7  100654.0    1002  Alabama A & M University  Public     1      199
# 8  100654.0    1002  Alabama A & M University  Public     1      199
# 9  100654.0    1002  Alabama A & M University  Public     1      199
#
#                                              CIPDESC  CREDLEV  \
# 0                              Agriculture, General.        3
# 1              Agricultural Business and Management.        3
# ...

# %%
print(df_csv.dtypes)
print('='*20)
print(df_csv.shape)
# Out:
# UNITID                       float64
# OPEID6                         int64
# INSTNM                        object
# CONTROL                       object
# MAIN                           int64
#                               ...
# EARN_MALE_WNE_MDN_5YR        float64
# EARN_COUNT_NOMALE_WNE_5YR    float64
# EARN_NOMALE_WNE_MDN_5YR      float64
# EARN_COUNT_HIGH_CRED_5YR     float64
# EARN_IN_STATE_5YR            float64
# Length: 174, dtype: object
# ...
# (214885, 174)

# %% [markdown]
# ## Aggregations

# %%
df_csv_agg = df_csv.groupby('CountryRegionCode').agg({
    'GeographyKey' : [('GeographyCount', 'count'), ('GeographyDistCount', 'nunique')],
    'PostalCode' : [('PostalMin', 'min'), ('PostalMax', 'max')],
})
df_csv_agg.head(10)
# Out:
#                     GeographyKey                    PostalCode
#                   GeographyCount GeographyDistCount  PostalMin PostalMac
# CountryRegionCode
# AU                            40                 40       1002      7001
# CA                            73                 73         7L   V9B 5T2
# DE                            65                 65      01071     95010
# FR                            48                 48      17490     95000
# GB                            53                 53       AS23      YO15
# US                           376                376      01906     99362
